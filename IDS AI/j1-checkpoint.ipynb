# %%
import numpy as np
import pandas as pd
import os
import cv2
import math
import random
import matplotlib.pyplot as plt
import shutil
from sklearn.preprocessing import QuantileTransformer
from PIL import Image
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
from PIL import Image

# %%
df=pd.read_csv(r"C:\Users\serpa\Dropbox\IDS AI\Car_Hacking_5%.csv")

# %%
df1=df[df["Label"]=='R']
df1
# Out:
#         CAN ID  DATA[0]  DATA[1]  DATA[2]  DATA[3]  DATA[4]  DATA[5]  DATA[6]  \
# 0         1201       41       39       39       35        0        0        0
# 1          809       64      187      127       20       17       32        0
# 2         1349      216        0        0      136        0        0        0
# 3         1201       41       39       39       35        0        0        0
# 4            2        0        0        0        0        0        3        2
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 818435     848        5       32       52      104      117        0        0
# 818436    1088      255        0        0        0      255      134        9
# 818437     848        5       32      100      104      117        0        0
# 818438    1349      216       90        0      137        0        0        0
# 818439     790        5       33       48       10       33       30        0
#
#         DATA[7] Label
# ...

# %%
df
# Out:
#         CAN ID  DATA[0]  DATA[1]  DATA[2]  DATA[3]  DATA[4]  DATA[5]  DATA[6]  \
# 0         1201       41       39       39       35        0        0        0
# 1          809       64      187      127       20       17       32        0
# 2         1349      216        0        0      136        0        0        0
# 3         1201       41       39       39       35        0        0        0
# 4            2        0        0        0        0        0        3        2
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 818435     848        5       32       52      104      117        0        0
# 818436    1088      255        0        0        0      255      134        9
# 818437     848        5       32      100      104      117        0        0
# 818438    1349      216       90        0      137        0        0        0
# 818439     790        5       33       48       10       33       30        0
#
#         DATA[7] Label
# ...

# %%
#R is indicates normal patterns , rest are 4 types of attacks

df.Label.value_counts()
# Out:
# Label
# R        701832
# RPM       32539
# gear      29944
# DoS       29501
# Fuzzy     24624
# Name: count, dtype: int64

# %%
#checking which one is attacking more
import seaborn as sns
data=df['Label'].where(df['Label']!='R')
plt.figure(figsize=(8,5))
chart=sns.countplot(data, palette="Set1")
plt.xlabel("Count")
plt.ylabel("types of Attack")
plt.title("Attack Count")
plt.xticks(rotation=45, horizontalalignment='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Transformation

# %%
# Transform all features into the scale of [0,1]
numeric_features = df.dtypes[df.dtypes != 'object'].index
scaler = QuantileTransformer()
df[numeric_features] = scaler.fit_transform(df[numeric_features])
# Multiply the feature values by 255 to transform them into the scale of [0,255]
df[numeric_features] = df[numeric_features].apply(
    lambda x: (x*255))

# %%
df.describe()
# Out:
#               CAN ID        DATA[0]        DATA[1]        DATA[2]  \
# count  818440.000000  818440.000000  818440.000000  818440.000000
# mean      127.702873     113.868912     108.513507      90.198807
# std        73.946317      90.284944      93.678218     101.218049
# min         0.000000       0.000000       0.000000       0.000000
# 25%        67.132132       0.000000       0.000000       0.000000
# 50%       121.501502     125.330330     116.396396       0.000000
# 75%       191.441441     193.866366     194.121622     200.630631
# max       255.000000     255.000000     255.000000     255.000000
#
#              DATA[3]        DATA[4]        DATA[5]        DATA[6]  \
# count  818440.000000  818440.000000  818440.000000  818440.000000
# mean      109.698859     105.517687     111.295598      85.187202
# std       103.578630      95.591111      90.586199     101.558589
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# **Generate image for each class**

# %%
# Create separate DataFrames for each attack type
df0 = df[df['Label'] == "R"].drop('Label', axis=1)
df1 =df[df['Label'] == "RPM"].drop('Label', axis=1)
df2 =df[df['Label'] == "gear"].drop('Label', axis=1)
df3 =df[df['Label'] == "DoS"].drop('Label', axis=1)
df4 =df[df['Label'] == "Fuzzy"].drop('Label', axis=1)

# %%
print(df0.shape)
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
# Out:
# (701832, 9)
# (32539, 9)
# (29944, 9)
# (29501, 9)
# (24624, 9)

# %%
#deleting path
import shutil

dir_path = "train"
shutil.rmtree(dir_path)

# %%
#for normal
count=0
ims = []

image_path = "train/0/"
os.makedirs(image_path)

for i in range(0, len(df0)):
    count=count+1
    if count<=27:
        im=df0.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
#for RPM
count=0
ims = []

image_path = "train/1/"
os.makedirs(image_path)

for i in range(0, len(df1)):
    count=count+1
    if count<=27:
        im=df1.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
#for Gear
count=0
ims=[]

image_path="train/2/"
os.makedirs(image_path)

for i in range(0, len(df2)):
    count=count+1
    if count<=27:
        im=df2.iloc[i].values
        ims=np.append(ims, im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array=np.array(ims, dtype=np.uint8)
        new_image=Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims=[]

# %%
#for DoS
count=0
ims=[]

image_path="train/3/"
os.makedirs(image_path)
for i in range(0, len(df3)):
    count=count+1
    if count<=27:
        im=df3.iloc[i].values
        ims=np.append(ims, im)
    else:
      ims=np.array(ims).reshape(9,9,3)
      array=np.array(ims, dtype=np.uint8)
      new_image=Image.fromarray(array)
      new_image.save(image_path+str(i)+'.png')
      count=0
      ims=[]

# %%
#for fuzzy
count=0
ims=[]

image_path="train/4/"
os.makedirs(image_path)

for i in range(0, len(df4)):
    count=count+1
    if count<=27:
        im=df4.iloc[i].values
        ims=np.append(ims, im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array=np.array(ims, dtype=np.uint8)
        new_image=Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims=[]

# %%
# Create folders to store images
Train_Dir='./train/'
Val_Dir='./test/'
allimgs=[]
for subdir in os.listdir(Train_Dir):
    for filename in os.listdir(os.path.join(Train_Dir,subdir)):
        filepath=os.path.join(Train_Dir,subdir,filename)
        allimgs.append(filepath)
print(len(allimgs)) # Print the total number of images
# Out:
# 29228

# %%
print(len(allimgs))
# Out:
# 29228

# %%
#split a test set from the dataset, train/test size = 80%/20%
Numbers=len(allimgs)//5 	#size of test set (20%)

def mymovefile(srcfile,dstfile):
    if not os.path.isfile(srcfile):
        print ("%s not exist!"%(srcfile))
    else:
        fpath,fname=os.path.split(dstfile)
        if not os.path.exists(fpath):
            os.makedirs(fpath)
        shutil.move(srcfile,dstfile)
        #print ("move %s -> %s"%(srcfile,dstfile))
Numbers
# Out:
# 5845

# %%
# Create the test set
val_imgs=random.sample(allimgs,Numbers)
for img in val_imgs:
    dest_path=img.replace(Train_Dir,Val_Dir)
    mymovefile(img,dest_path)
print('Finish creating test set')
# Out:
# Finish creating test set

# %%
#resize the images 224*224 for better CNN training
def get_224(folder,dstdir):
    imgfilepaths=[]
    for root,dirs,imgs in os.walk(folder):
        for thisimg in imgs:
            thisimg_path=os.path.join(root,thisimg)
            imgfilepaths.append(thisimg_path)
    for thisimg_path in imgfilepaths:
        dir_name,filename=os.path.split(thisimg_path)
        dir_name=dir_name.replace(folder,dstdir)
        new_file_path=os.path.join(dir_name,filename)
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)
        img=cv2.imread(thisimg_path)
        img=cv2.resize(img,(224,224))
        cv2.imwrite(new_file_path,img)
    print('Finish resizing'.format(folder=folder))

# %%
DATA_DIR_224='./train_224/'
get_224(folder='./train/',dstdir=DATA_DIR_224)
# Out:
# Finish resizing

# %%
DATA_DIR2_224='./test_224/'
get_224(folder='./test/',dstdir=DATA_DIR2_224)
# Out:
# Finish resizing

# %%
# Read the images for each category, the file name may vary (27.png, 83.png...)
img1 = Image.open('./train_224/0/100015.png')
img2 = Image.open('./train_224/1/27.png')
img3 = Image.open('./train_224/2/10079.png')
img4 = Image.open('./train_224/3/1007.png')
img5 = Image.open('./train_224/4/10079.png')

plt.figure(figsize=(10,9))
plt.subplot(1,5,1)
plt.imshow(img1)
plt.title("Normal")
plt.subplot(1,5,2)
plt.imshow(img2)
plt.title("RPM Spoofing")
plt.subplot(1,5,3)
plt.imshow(img3)
plt.title("Gear Spoofing")
plt.subplot(1,5,4)
plt.imshow(img4)
plt.title("DoS Attack")
plt.subplot(1,5,5)
plt.imshow(img5)
plt.title("Fuzzy Attack")
plt.show()  # display it

# %% [markdown]
# ***TRAINING***

# %%
import os
import time

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Sequential
from keras.optimizers import Adam
from keras.regularizers import l2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.mixed_precision import set_global_policy, Policy

# --- Constants and Hyperparameters ---

TARGET_SIZE = (224, 224)
INPUT_SIZE = (224, 224, 3)
BATCH_SIZE = 32 # Experiment with this value based on your system's memory
NUM_CLASSES = 5
EPOCHS = 20

# --- Data Generators with Augmentation ---

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    './train_224/',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    './test_224/',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# --- Model Definition ---

def cnn_model(input_shape, num_class):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), strides=(1, 1), input_shape=input_shape, padding='same', activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(rate=0.5))
    model.add(Dense(num_class, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# --- Main Execution ---

if __name__ == "__main__":

    # Mixed Precision (Optional - TensorFlow 2.4+ and compatible GPU)
    # Uncomment if you have the required setup
    # set_global_policy(Policy('mixed_float16'))

    # Create and train the model
    model = cnn_model(input_shape=INPUT_SIZE, num_class=NUM_CLASSES)
    print(model.summary())

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    save_best_model = ModelCheckpoint(filepath='./models/cnn_model.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001)

    start_time = time.time()  # Record start time

    model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=len(validation_generator),
        callbacks=[early_stopping, save_best_model, reduce_lr]
    )

    end_time = time.time()  # Record end time
    print(f"Training completed in {end_time - start_time:.2f} seconds")
# Out:
# Found 29183 images belonging to 5 classes.
# Found 17225 images belonging to 5 classes.
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 112, 112, 32)        │               0 │
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

from keras.models import load_model as keras_load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --- Constants and Data Generators ---
TARGET_SIZE = (224, 224)
BATCH_SIZE = 32 

test_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = test_datagen.flow_from_directory(
    './test_224/',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False 
)

# --- Model Loading ---

def load_model(model_path=os.path.join('models', 'cnn_model.keras')):
    """
    Loads the trained Keras model from the specified path.

    Args:
        model_path (str, optional): The path to the saved Keras model file.
                                    Defaults to './models/cnn_model.keras'.

    Returns:
        keras.Model: The loaded Keras model.
    """
    return keras_load_model(model_path)

# --- Evaluation Functions ---

def evaluate_model(model, generator):
    """
    Evaluates the model on the given data generator and prints metrics.

    Args:
        model (keras.Model): The trained Keras model.
        generator (ImageDataGenerator): The data generator for the evaluation data.
    """

    # 1. Overall Performance Metrics 
    loss, accuracy = model.evaluate(generator)
    print(f"\nModel Evaluation:")
    print(f"Loss: {loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")

    # 2. Predictions for Detailed Analysis
    y_true = generator.classes  # True labels
    y_pred = model.predict(generator).argmax(axis=1)  # Predicted labels

    # 3. Classification Report
    print("\nClassification Report:")
    target_names = [str(i) for i in range(generator.num_classes)]
    print(classification_report(y_true, y_pred, target_names=target_names))

    # 4. Confusion Matrix
    print("\nConfusion Matrix:")
    print(confusion_matrix(y_true, y_pred))

# --- Main Execution ---

if __name__ == "__main__":
    # Load the trained model 
    model = load_model()

    # Evaluate the model 
    evaluate_model(model, validation_generator)
# Out:
# Found 17225 images belonging to 5 classes.
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 98s 181ms/step - accuracy: 1.0000 - loss: 0.0226
#
# Model Evaluation:
# Loss: 0.0226
# Accuracy: 1.0000
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 98s 181ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14772
#            1       1.00      1.00      1.00       702
#            2       1.00      1.00      1.00       638
#            3       1.00      1.00      1.00       597
#            4       1.00      1.00      1.00       516
#
#     accuracy                           1.00     17225
#    macro avg       1.00      1.00      1.00     17225
# weighted avg       1.00      1.00      1.00     17225
#
#
# Confusion Matrix:
# [[14772     0     0     0     0]
#  [    0   702     0     0     0]
#  [    0     0   638     0     0]
#  [    0     0     0   597     0]
#  [    0     0     0     0   516]]

# %%
# Retrain the model for a few epochs
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=2,  # Number of additional epochs
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[early_stopping, save_best_model, reduce_lr]
)

# Now you have the history object
# Out:
# Epoch 1/2
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9983 - loss: 0.0381
# Epoch 1: val_loss did not improve from 0.02263
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 2708s 3s/step - accuracy: 0.9983 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0381 - learning_rate: 2.0000e-04
# Epoch 2/2
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 0s 94us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.0000e-04
# C:\Users\serpa\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# C:\Users\serpa\anaconda3\Lib\site-packages\keras\src\callbacks\early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# ...

# %% [markdown]
# ***TEST***

# %%
import warnings
warnings.filterwarnings("ignore")
import keras
from keras.models import Model,load_model
from keras import Input
from keras.layers import concatenate,Dense,Flatten,Dropout

import keras.callbacks as kcallbacks
import os
import math
from keras.utils import plot_model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, LearningRateScheduler
from keras.optimizers import SGD
import operator
import numpy as np
from PIL import Image
from collections import defaultdict

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ***Read the test set***

# %%
#generate images from train set and validation set
TARGET_SIZE=(224,224)
INPUT_SIZE=(224,224,3)
BATCHSIZE=128

test_datagen = ImageDataGenerator(rescale=1./255)


validation_generator = test_datagen.flow_from_directory(
        './test_224/',
        target_size=TARGET_SIZE,
        batch_size=BATCHSIZE,
        class_mode='categorical')
# Out:
# Found 17225 images belonging to 5 classes.

# %%
label = validation_generator.class_indices

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from keras.models import load_model

# Define a dictionary mapping labels to attack types
label_to_attack = {
    '0': 'Normal Message',
    '1': 'DoS Attack',
    '2': 'Fuzzy Attack',
    '3': 'Gear Spoofing Attack',
    '4': 'RPM Spoofing Attack'
}

# Load your custom CNN model 
model = load_model('./models/cnn_model.keras')  

# Specify the full path to the image you want to test
test_image_path = './test_224/3/83.png'  # Replace with your actual image path

# Get the class label from the directory name (assuming the directory structure reflects the class)
predicted_label = test_image_path.split('/')[-2] 
predicted_attack = label_to_attack[predicted_label] 

# Load and preprocess the image
test_image = cv2.imread(test_image_path)
img_show = test_image[:, :, [2, 1, 0]]  # Convert BGR to RGB for displaying with matplotlib
test_image = test_image / 255.0  # Normalize the image
test_image = np.expand_dims(test_image, axis=0)  # Add batch dimension

# Make prediction
predictions = model.predict(test_image)

# Get the confidence
confidence = np.max(predictions) 

# Print results and display image with title
print('Predicted result for the selected image:', predicted_label, '-', predicted_attack)
print('Confidence level:', confidence)
plt.imshow(img_show)
plt.title(f'Predicted: {predicted_label} - {predicted_attack} ({confidence:.2f})') 
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Predicted result for the selected image: 3 - Gear Spoofing Attack
# Confidence level: 1.0
